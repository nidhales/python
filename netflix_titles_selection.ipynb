# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhales/python/blob/main/netflix_titles_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
df["country"]
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7782    Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                                India
# 7784                                                  NaN
# 7785                                            Australia
# 7786                United Kingdom, Canada, United States
# Name: country, Length: 7787, dtype: object

# %%
df["country"].head()
# Out:
# 0           Brazil
# 1           Mexico
# 2        Singapore
# 3    United States
# 4    United States
# Name: country, dtype: object

# %%
df.country.head()
# Out:
# 0           Brazil
# 1           Mexico
# 2        Singapore
# 3    United States
# 4    United States
# Name: country, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.country)
# Out:
# pandas.core.series.Series

# %%
df[10:20]
# Out:
#    show_id  ...                                        description
# 10     s11  ...  A farmer pens a confession admitting to his wi...
# 11     s12  ...  In this dark alt-history thriller, a naïve law...
# 12     s13  ...  Archival video and new interviews examine Mexi...
# 13     s14  ...  This intimate documentary follows rock star Ar...
# 14     s15  ...  Stranded when the Earth is suddenly destroyed ...
# 15     s16  ...  Against the backdrop of Nigeria's looming inde...
# 16     s17  ...  As a psychology professor faces Alzheimer's, h...
# 17     s18  ...  After devastating terror attacks in Norway, a ...
# 18     s19  ...  On India's Independence Day, a zany mishap in ...
# 19     s20  ...  Mixing old footage with interviews, this is th...
#
# [10 rows x 12 columns]

# %%
df.loc[10:13]
# Out:
#    show_id  ...                                        description
# 10     s11  ...  A farmer pens a confession admitting to his wi...
# 11     s12  ...  In this dark alt-history thriller, a naïve law...
# 12     s13  ...  Archival video and new interviews examine Mexi...
# 13     s14  ...  This intimate documentary follows rock star Ar...
#
# [4 rows x 12 columns]

# %%
df_country=df.set_index("country")

# %%
df_country.head()
# Out:
#               show_id  ...                                        description
# country                ...
# Brazil             s1  ...  In a future where the elite inhabit an island ...
# Mexico             s2  ...  After a devastating earthquake hits Mexico Cit...
# Singapore          s3  ...  When an army recruit is found dead, his fellow...
# United States      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# United States      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 11 columns]

# %%
df_country.loc["Mexico"]
# Out:
#         show_id  ...                                        description
# country          ...
# Mexico       s2  ...  After a devastating earthquake hits Mexico Cit...
# Mexico      s13  ...  Archival video and new interviews examine Mexi...
# Mexico     s293  ...  Three lifelong friends travel to Acapulco oste...
# Mexico     s371  ...  Mexican comic Alan Saldaña has fun with everyt...
# Mexico     s379  ...  Comic Alex Fernández performs his familiar aut...
# ...         ...  ...                                                ...
# Mexico    s7699  ...  On the run from the police, an Arizona man cro...
# Mexico    s7726  ...  A nurse and her daughter flee her husband’s dr...
# Mexico    s7735  ...  An ad creative and a successful exec have a gr...
# Mexico    s7774  ...  This introspective rockumentary follows the ca...
# Mexico    s7780  ...  An assortment of talent takes the stage for a ...
#
# [100 rows x 11 columns]

# %%
type(df_country.loc["Mexico"])
# Out:
# pandas.core.frame.DataFrame

# %%
df_country.loc["Mexico"].values
# Out:
# array([['s2', 'Movie', '07:19', ..., '93 min',
#         'Dramas, International Movies',
#         'After a devastating earthquake hits Mexico City, trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive.'],
#        ['s13', 'TV Show', '1994', ..., '1 Season',
#         'Crime TV Shows, Docuseries, International TV Shows',
#         'Archival video and new interviews examine Mexican politics in 1994, a year marked by the rise of the EZLN and the assassination of Luis Donaldo Colosio.'],
#        ['s293', 'Movie', 'Acapulco La vida va', ..., '89 min',
#         'Comedies, Dramas, International Movies',
#         'Three lifelong friends travel to Acapulco ostensibly so one of them can find his lost love, but the real reason behind the trip holds some surprises.'],
#        ...,
#        ['s7735', 'Movie', "You've Got This", ..., '112 min',
#         'Comedies, International Movies, Romantic Movies',
# ...

# %%
df_country.loc["Mexico"].values.tolist()
# Out:
# [['s2',
#   'Movie',
#   '07:19',
#   'Jorge Michel Grau',
#   'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato',
#   'December 23, 2016',
#   2016,
#   'TV-MA',
#   '93 min',
#   'Dramas, International Movies',
#   'After a devastating earthquake hits Mexico City, trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive.'],
#  ['s13',
#   'TV Show',
#   '1994',
#   'Diego Enrique Osorno',
#   nan,
#   'May 17, 2019',
#   2019,
#   'TV-MA',
#   '1 Season',
#   'Crime TV Shows, Docuseries, International TV Shows',
#   'Archival video and new interviews examine Mexican politics in 1994, a year marked by the rise of the EZLN and the assassination of Luis Donaldo Colosio.'],
#  ['s293',
#   'Movie',
#   'Acapulco La vida va',
#   'Alfonso Serrano Maturino',
#   'Patricio Castillo, Sergio Bustamante, Alejandro Suárez, Luz María Jerez, Bob Isaacs, Tere Monroy',
#   'June 3, 2017',
#   2016,
#   'TV-MA',
# ...

# %%
l=df_country.loc["Mexico"].values.tolist()

# %%
l
# Out:
# [['s2',
#   'Movie',
#   '07:19',
#   'Jorge Michel Grau',
#   'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato',
#   'December 23, 2016',
#   2016,
#   'TV-MA',
#   '93 min',
#   'Dramas, International Movies',
#   'After a devastating earthquake hits Mexico City, trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive.'],
#  ['s13',
#   'TV Show',
#   '1994',
#   'Diego Enrique Osorno',
#   nan,
#   'May 17, 2019',
#   2019,
#   'TV-MA',
#   '1 Season',
#   'Crime TV Shows, Docuseries, International TV Shows',
#   'Archival video and new interviews examine Mexican politics in 1994, a year marked by the rise of the EZLN and the assassination of Luis Donaldo Colosio.'],
#  ['s293',
#   'Movie',
#   'Acapulco La vida va',
#   'Alfonso Serrano Maturino',
#   'Patricio Castillo, Sergio Bustamante, Alejandro Suárez, Luz María Jerez, Bob Isaacs, Tere Monroy',
#   'June 3, 2017',
#   2016,
#   'TV-MA',
# ...

# %%
df_country
# Out:
#                                                    show_id  ...                                        description
# country                                                     ...
# Brazil                                                  s1  ...  In a future where the elite inhabit an island ...
# Mexico                                                  s2  ...  After a devastating earthquake hits Mexico Cit...
# Singapore                                               s3  ...  When an army recruit is found dead, his fellow...
# United States                                           s4  ...  In a postapocalyptic world, rag-doll robots hi...
# United States                                           s5  ...  A brilliant group of students become card-coun...
# ...                                                    ...  ...                                                ...
# ...

# %%
df_country.loc[["Mexico","Australia"]]
# Out:
#           show_id  ...                                        description
# country            ...
# Mexico         s2  ...  After a devastating earthquake hits Mexico Cit...
# Mexico        s13  ...  Archival video and new interviews examine Mexi...
# Mexico       s293  ...  Three lifelong friends travel to Acapulco oste...
# Mexico       s371  ...  Mexican comic Alan Saldaña has fun with everyt...
# Mexico       s379  ...  Comic Alex Fernández performs his familiar aut...
# ...           ...  ...                                                ...
# Australia   s7535  ...  Bea Smith is locked up while awaiting trial fo...
# Australia   s7636  ...  After the death of a long-ago lover, married p...
# Australia   s7675  ...  In 1970s Melbourne, a DJ named Boori Monty Pry...
# Australia   s7753  ...  It's drama Down Under when expectant mothers w...
# Australia   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
#
# [183 rows x 11 columns]

# %%
type(df_country.loc[["Mexico","Australia"]])
# Out:
# pandas.core.frame.DataFrame
