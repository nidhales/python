# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhales/python/blob/main/netflix_titles_supprimerDonnee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df=pd.read_csv("netflix_titles.csv")

# %%
df.drop("title" , axis=1,inplace=True)

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 11 columns]

# %% [markdown]
# # supprimer les lignes qui ont le direceur ="NaN	"

# %%
df.set_index("cast", inplace=True)

# %%
df
# Out:
#                                                    show_id  ...                                        description
# cast                                                        ...
# João Miguel, Bianca Comparato, Michel Gomes, Ro...      s1  ...  In a future where the elite inhabit an island ...
# Demián Bichir, Héctor Bonilla, Oscar Serrano, A...      s2  ...  After a devastating earthquake hits Mexico Cit...
# Tedd Chan, Stella Chung, Henley Hii, Lawrence K...      s3  ...  When an army recruit is found dead, his fellow...
# Elijah Wood, John C. Reilly, Jennifer Connelly,...      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaro...      s5  ...  A brilliant group of students become card-coun...
# ...                                                    ...  ...                                                ...
# ...

# %%
df.drop("Nasty C", axis=0,inplace=True)

# %%
df.head()
# Out:
#                                                    show_id  ...                                        description
# cast                                                        ...
# João Miguel, Bianca Comparato, Michel Gomes, Ro...      s1  ...  In a future where the elite inhabit an island ...
# Demián Bichir, Héctor Bonilla, Oscar Serrano, A...      s2  ...  After a devastating earthquake hits Mexico Cit...
# Tedd Chan, Stella Chung, Henley Hii, Lawrence K...      s3  ...  When an army recruit is found dead, his fellow...
# Elijah Wood, John C. Reilly, Jennifer Connelly,...      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaro...      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 9 columns]

# %%
df.drop(["listed_in","country","type"],axis=1,inplace=True)

# %%
df
# Out:
#                                                    show_id  ...                                        description
# cast                                                        ...
# João Miguel, Bianca Comparato, Michel Gomes, Ro...      s1  ...  In a future where the elite inhabit an island ...
# Demián Bichir, Héctor Bonilla, Oscar Serrano, A...      s2  ...  After a devastating earthquake hits Mexico Cit...
# Tedd Chan, Stella Chung, Henley Hii, Lawrence K...      s3  ...  When an army recruit is found dead, his fellow...
# Elijah Wood, John C. Reilly, Jennifer Connelly,...      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaro...      s5  ...  A brilliant group of students become card-coun...
# ...                                                    ...  ...                                                ...
# ...

# %% [markdown]
# autre méthode de suppression

# %%
del df.show_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-b5c607dd3708> in <module>()
# ----> 1 del df.show_id
#
# AttributeError: show_id

# %%
del df["show_id"]

# %%
df
# Out:
#                                                            date_added  ...                                        description
# cast                                                                   ...
# João Miguel, Bianca Comparato, Michel Gomes, Ro...    August 14, 2020  ...  In a future where the elite inhabit an island ...
# Demián Bichir, Héctor Bonilla, Oscar Serrano, A...  December 23, 2016  ...  After a devastating earthquake hits Mexico Cit...
# Tedd Chan, Stella Chung, Henley Hii, Lawrence K...  December 20, 2018  ...  When an army recruit is found dead, his fellow...
# Elijah Wood, John C. Reilly, Jennifer Connelly,...  November 16, 2017  ...  In a postapocalyptic world, rag-doll robots hi...
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaro...    January 1, 2020  ...  A brilliant group of students become card-coun...
# ...                                                               ...  ...                                                ...
# ...

# %% [markdown]
#  #traiter des valeurs manquantes

# %% [markdown]
# autre méthode de suppression

# %%
df[df.rating.isnull()]
# Out:
#                                                             date_added  ...                                        description
# cast                                                                    ...
# Oprah Winfrey, Ava DuVernay                           January 26, 2017  ...  Oprah Winfrey sits down with director Ava DuVe...
# Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Kan...    December 1, 2016  ...  After falling through a wormhole, a space-dwel...
# Flynn Curry, Olivia Deeble, Madison Lu, Oisín O...    February 1, 2018  ...  Adopting a child's perspective, this show take...
# Louis C.K.                                               April 4, 2017  ...  Louis C.K. muses on religion, eternal love, gi...
# Louis C.K.                                          September 16, 2016  ...  Emmy-winning comedy writer Louis C.K. brings h...
# Louis C.K.                                             August 15, 2016  ...  The comic puts his trademark hilarious/thought...
# ...

# %%
df["rating"].fillna(0)
# Out:
# cast
# João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi    TV-MA
# Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato                                                                                      TV-MA
# Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim                                                                      R
# Elijah Wood, John C. Reilly, Jennifer Connelly, Christopher Plummer, Crispin Glover, Martin Landau, Fred Tatasciore, Alan Oppenheimer, Tom Kane                               PG-13
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaron Yoo, Liza Lapira, Jacob Pitts, Laurence Fishburne, Jack McGee, Josh Gad, Sam Golzari, Helen Carey, Jack Gilpin               PG-13
# ...

# %%
df["rating"].fillna(method='bfill')
# Out:
# cast
# João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi    TV-MA
# Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato                                                                                      TV-MA
# Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim                                                                      R
# Elijah Wood, John C. Reilly, Jennifer Connelly, Christopher Plummer, Crispin Glover, Martin Landau, Fred Tatasciore, Alan Oppenheimer, Tom Kane                               PG-13
# Jim Sturgess, Kevin Spacey, Kate Bosworth, Aaron Yoo, Liza Lapira, Jacob Pitts, Laurence Fishburne, Jack McGee, Josh Gad, Sam Golzari, Helen Carey, Jack Gilpin               PG-13
# ...

# %% [markdown]
# supprimer les rangés qui comporte des données "null"

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df.dropna()
# Out:
#      show_id  ...                                        description
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# 5         s6  ...  A genetics professor experiments with a treatm...
# ...      ...  ...                                                ...
# 7778   s7779  ...  Looking to survive in a world taken over by zo...
# 7780   s7781  ...  A drug dealer starts having doubts about his t...
# 7781   s7782  ...  Dragged from civilian life, a former superhero...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
#
# [4808 rows x 12 columns]

# %% [markdown]
# **texte en gras**# ajouter des valeur selon les colonnes le plus proches

# %%
df["title"].fillna(method='bfill')
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7782                                       Zozo
# 7783                                     Zubaan
# 7784                          Zulu Man in Japan
# 7785                      Zumbo's Just Desserts
# 7786    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: title, Length: 7787, dtype: object

# %% [markdown]
# [texte du lien](https://)# `supprimer les rangés qui comporte des données "null"`

# %%
df.dropna(subset=['title'], inplace=True)

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]
