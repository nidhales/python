# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhales/python/blob/main/netflix_titles_ajouterColonne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df=pd.read_csv("netflix_titles.csv")

# %%
df['cast'].fillna(0,inplace=True)

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 2719   s2720  ...  Pop stars and impersonators face off to be the...
# 2720   s2721  ...  While investigating an actress’s supposed suic...
# 2721   s2722  ...  Years after an accident at a wild Christmas pa...
# 2722   s2723  ...  While living a comfortable life with his wife ...
# 2723   s2724  ...                                                NaN
#
# [2724 rows x 12 columns]

# %% [markdown]
# ajouter une colonne

# %%
df['test']=0

# %%
df
# Out:
#      show_id     type  ...                                        description test
# 0         s1  TV Show  ...  In a future where the elite inhabit an island ...    0
# 1         s2    Movie  ...  After a devastating earthquake hits Mexico Cit...    0
# 2         s3    Movie  ...  When an army recruit is found dead, his fellow...    0
# 3         s4    Movie  ...  In a postapocalyptic world, rag-doll robots hi...    0
# 4         s5    Movie  ...  A brilliant group of students become card-coun...    0
# ...      ...      ...  ...                                                ...  ...
# 2719   s2720  TV Show  ...  Pop stars and impersonators face off to be the...    0
# 2720   s2721  TV Show  ...  While investigating an actress’s supposed suic...    0
# 2721   s2722    Movie  ...  Years after an accident at a wild Christmas pa...    0
# 2722   s2723    Movie  ...  While living a comfortable life with his wife ...    0
# ...

# %%
del df['test']

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 2719   s2720  ...  Pop stars and impersonators face off to be the...
# 2720   s2721  ...  While investigating an actress’s supposed suic...
# 2721   s2722  ...  Years after an accident at a wild Christmas pa...
# 2722   s2723  ...  While living a comfortable life with his wife ...
# 2723   s2724  ...                                                NaN
#
# [2724 rows x 12 columns]

# %%
df.type=df.type.apply(lambda x:x.replace("$",""))
df.type=df.type.astype(object)
df[df.type=="Movie"]
# Out:
#      show_id  ...                                        description
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# 6         s7  ...  After an awful accident, a couple admitted to ...
# ...      ...  ...                                                ...
# 2717   s2718  ...  While serving as the marshal of rowdy Abilene,...
# 2718   s2719  ...  A woman stages her own suicide but still lives...
# 2721   s2722  ...  Years after an accident at a wild Christmas pa...
# 2722   s2723  ...  While living a comfortable life with his wife ...
# 2723   s2724  ...                                                NaN
#
# [1893 rows x 12 columns]

# %%
df['type']=df['type']+[' ']+df['show_id']

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 2719   s2720  ...  Pop stars and impersonators face off to be the...
# 2720   s2721  ...  While investigating an actress’s supposed suic...
# 2721   s2722  ...  Years after an accident at a wild Christmas pa...
# 2722   s2723  ...  While living a comfortable life with his wife ...
# 2723   s2724  ...                                                NaN
#
# [2724 rows x 12 columns]

# %%
del df['type']

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 2719   s2720  ...  Pop stars and impersonators face off to be the...
# 2720   s2721  ...  While investigating an actress’s supposed suic...
# 2721   s2722  ...  Years after an accident at a wild Christmas pa...
# 2722   s2723  ...  While living a comfortable life with his wife ...
# 2723   s2724  ...                                                NaN
#
# [2724 rows x 11 columns]

# %%
df['donnée']=df['title']+[' ']+df['rating']

# %%
df
# Out:
#      show_id  ...                      donnée
# 0         s1  ...                    3% TV-MA
# 1         s2  ...                 07:19 TV-MA
# 2         s3  ...                     23:59 R
# 3         s4  ...                     9 PG-13
# 4         s5  ...                    21 PG-13
# ...      ...  ...                         ...
# 2719   s2720  ...         Hidden Singer TV-Y7
# 2720   s2721  ...         Hidden Worlds TV-14
# 2721   s2722  ...           Hide & Seek TV-14
# 2722   s2723  ...         Hide and Seek TV-14
# 2723   s2724  ...  High & Low The Movie TV-MA
#
# [2724 rows x 12 columns]

# %%
country={"Japan": "JP","India":"IN", "Egypt":"EGY"}
df["Country_Code"]=df["country"].map(country)

# %%
df
# Out:
#      show_id                 title  ...                      donnée Country_Code
# 0         s1                    3%  ...                    3% TV-MA          NaN
# 1         s2                 07:19  ...                 07:19 TV-MA          NaN
# 2         s3                 23:59  ...                     23:59 R          NaN
# 3         s4                     9  ...                     9 PG-13          NaN
# 4         s5                    21  ...                    21 PG-13          NaN
# ...      ...                   ...  ...                         ...          ...
# 2719   s2720         Hidden Singer  ...         Hidden Singer TV-Y7          NaN
# 2720   s2721         Hidden Worlds  ...         Hidden Worlds TV-14          EGY
# 2721   s2722           Hide & Seek  ...           Hide & Seek TV-14           IN
# 2722   s2723         Hide and Seek  ...         Hide and Seek TV-14          NaN
# 2723   s2724  High & Low The Movie  ...  High & Low The Movie TV-MA           JP
#
# ...
